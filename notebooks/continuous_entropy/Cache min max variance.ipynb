# %%
from ensemblepy.densityvar import generate_cache
vs = generate_cache(timings=True)
print(vs)
# Out:
# {(20, (-0.1, 1.1), 2000, 1): (0.0008574780498222127, 0.03523253847900814), (20, (-0.1, 1.1), 2000, 2): (2.7103066387859285e-05, 0.02612781672523911), (20, (-0.1, 1.1), 2000, 3): (8.803400607879815e-07, 0.02178976283081503), (20, (-0.1, 1.1), 2000, 4): (2.6697988705817088e-08, 0.01911461767461143), (20, (-0.1, 1.1), 2000, 5): (1.4024042383936424e-09, 0.017249518532083768), (20, (-0.1, 1.1), 2000, 6): (2.9306774540492626e-09, 0.015851438407103617), (20, (-0.1, 1.1), 2000, 7): (8.013432381742634e-09, 0.014751934907515835), (20, (-0.1, 1.1), 2000, 8): (8.454413758960009e-10, 0.01385720940344645), (20, (-0.1, 1.1), 2000, 9): (9.415732326117289e-08, 0.01311027046537127), (20, (-0.1, 1.1), 2000, 10): (2.247188451401996e-08, 0.012474193951663467), (20, (-0.1, 1.1), 2000, 11): (5.385425127326677e-09, 0.011923847125716718), (20, (-0.1, 1.1), 2000, 12): (1.2950833646212431e-09, 0.01144144040632065), (20, (-0.1, 1.1), 2000, 13): (3.123516791845998e-10, 0.011013974758823137), (20, (-0.1, 1.1), 20
# ...
