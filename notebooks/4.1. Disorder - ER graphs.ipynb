# %%
import nbsetup
import numpy as np
import ergodicpy as ep
from simulations.graphs.models import ERGraph

# %%
def series(nodes, ensembles=20, x=None):
    if x is None:
        x = np.linspace(0, 1, 100)
    y = []
    # generate data
    for p in x:
        y.append([ERGraph(nodes, p).edges_counts() for _ in range(ensembles)])
    # analyse
    ees = ep.ErgodicSeries(x=x, y=y, x_label='p', bins=ep.binr(0,nodes,nodes))
    ees.plot()
    return ees

# %% [markdown]
# # Balancing disorder
#
# Erdos-Renyi Graphs are good examples of how a system approaches disorder. Where initially the start with high order (i.e. _p=0_ where p is the probability that a node will connect with another node, so highly ordered as they're all entirely disconnected).
#
# When _p=0.5_ this is where the system is most disordered. However, what we see below is although the system is most disordered in this state, therefore has the highest entropy, the ergodic complexity in this case remains low. As all ensembles have the same high entropy, there's no interesting structure there.

# %%
hundred = series(100)

# %% [markdown]
# # Tipping point
#
# What is interesting in these results, is there appears to be a tipping point right around the boundary of order to become disordered. As some systems are go from having basically zero connections, to some connections.
#
# However, since it's at the bounds of the possible it's hard to think of this as a tipping point.
#
# Zooming in and boosting the granularity around 0 for 100 nodes i.e. looking from p=0.0 to p=0.01 for 100 steps

# %%
hundred_cut = series(100, x=np.linspace(0,0.01,100))

# %% [markdown]
# We can see this as being more pronounced with fewer nodes where that difference makes a bigger difference to the system overall.

# %%
ten = series(15)
