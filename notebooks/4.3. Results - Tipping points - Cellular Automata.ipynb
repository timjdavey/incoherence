# %%
import nbsetup as nb
import ergodicpy as ep
from simulations.automata.models import CA1DEnsemble

# %%
ca = CA1DEnsemble(rule=30, cells=100, count=20, init='sparse')
ca.run(100) # timesteps
ca.analyse()
ca.analysis
# Out:
#     Avg Cell Entropy  Avg Stable Cell Entropy  Last Cell Entropy  \
# 0           0.992747                 0.986842           0.997402
# 1           0.988020                 0.979998           0.985815
# 2           0.993862                 0.987321           0.999711
# 3           0.993615                 0.989379           0.995378
# 4           0.991810                 0.981050           0.999711
# 5           0.989262                 0.986156           0.997402
# 6           0.993686                 0.988785           0.985815
# 7           0.986319                 0.983327           0.998846
# 8           0.978716                 0.988472           0.997402
# 9           0.992971                 0.986016           0.970951
# 10          0.994407                 0.987544           0.976500
# 11          0.992547                 0.988752           0.970951
# 12          0.993504                 0.988797           1.000000
# ...
