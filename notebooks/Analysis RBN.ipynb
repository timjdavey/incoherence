# %%
import nbsetup
import seaborn as sns
import pandas as pd

from simulations.rbn.RBN import UnorderedTruthTable, ExactRBN

# %%
NODES = 200
EDGES = 3
table = UnorderedTruthTable(EDGES)

# %%
model = ExactRBN(NODES, EDGES, table)
RUNS = 200
model.run_model(RUNS)
model.plot_ca()

# %%
import networkx as nx
nx.draw_spectral(model.G)

# %%
model.table.table
# Out:
# {0: 1, 1: 0, 2: 0, 3: 1}
