# %%
import nbsetup
import ensemblepy as ep
import numpy as np
import seaborn as sns
import scipy as sp
import pandas as pd
from simulations.snowflake.models import Snowflake, SnowVerse
import matplotlib.pyplot as plt
import copy

# %%
sfs = [Snowflake() for i in range(5)]

# %%
SnowVerse()
