# %% [markdown]
# with 1/moment

# %%
import nbsetup as nb
import numpy as np
import ergodicpy as ep

from simulations.daisy_world.series import series, scan

# %%
worlds, fig = scan(np.linspace(0.4, 0.7, 10), steps=200, cp=nb.cp)

# %%
worlds[0.5333333333333333].results(True)

# %%
worlds[0.7].plot()
