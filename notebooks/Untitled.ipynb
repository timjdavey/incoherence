# %% [markdown]
# without

# %%
import nbsetup as nb
import numpy as np
import ergodicpy as ep

from simulations.daisy_world.series import series, scan

# %%
worlds, fig = scan(np.linspace(0.4, 1.0, 10), steps=100, cp=nb.cp)

# %%
worlds[0.5333333333333333].plot()

# %%
worlds[0.7333333333333334].plot()
