# %%
import nbsetup
from simulations.automata.models import CA1DEnsemble
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Cellular Automata

# %% [markdown]
# Show results for specific Wolfram rules.
#
# Uses a standard set of conditions of 100 cell width, 100 timestep depth, for 20 ensembles. Starting with an initial sparse layout, where only 10% of the cells start as 1 the rest are 0.

# %% [markdown]
# ## Ordered or mechanistic examples

# %%
zero = CA1DEnsemble(rule=0, cells=100, count=20, init='sparse').show(100)

# %%
zero.get_analysis('complexity')
# Out:
#     Avg Stable Cell Entropy  Stable diag LR  Stable diag RL
# 21                      0.0             0.0             0.0

# %%
ca127 = CA1DEnsemble(rule=127, cells=100, count=20, init='sparse').show(100)

# %%
ca253 = CA1DEnsemble(rule=253, cells=100, count=20, init='sparse').show(100)

# %% [markdown]
# ## Ergodically complex examples

# %%
ca218 = CA1DEnsemble(rule=218, cells=100, count=20, init='sparse').show(100)

# %%
ca218.get_analysis('complexity')
# Out:
#     Avg Stable Cell Entropy  Stable diag LR  Stable diag RL
# 21                 0.381246        0.198137        0.195653

# %%
ca99 = CA1DEnsemble(rule=99, cells=100, count=20, init='sparse').show(100)

# %%
ca225 = CA1DEnsemble(rule=225, cells=100, count=20, init='sparse').show(100)

# %% [markdown]
# ## Disordered examples

# %%
# famously random as Wolframe patented this rule to use as a random number generator
ca30 = CA1DEnsemble(rule=30, cells=100, count=20, init='sparse').show(100)

# %%
ca30.get_analysis('complexity')
# Out:
#     Avg Stable Cell Entropy  Stable diag LR  Stable diag RL
# 21                 0.014311        0.021056        0.046394

# %%
ca165 = CA1DEnsemble(rule=165, cells=100, count=20, init='sparse').show(100)

# %%
ca105 = CA1DEnsemble(rule=105, cells=100, count=20, init='sparse').show(100)

# %% [markdown]
# ## Figures for paper

# %%
if True:
    zero.plot().savefig('figures/4.1-ca-0.eps')
    ca218.plot().savefig('figures/4.1-ca-218.eps')
    ca30.plot().savefig('figures/4.1-ca-30.eps')
