# %%
import numpy as np
for i in range(50, 10000, 100):
    b = int(np.log2(i)/)
    print(i, b, int(i/b))
# Out:
# 50 5 10
# 150 7 21
# 250 7 35
# 350 8 43
# 450 8 56
# 550 9 61
# 650 9 72
# 750 9 83
# 850 9 94
# 950 9 105
# 1050 10 105
# 1150 10 115
# 1250 10 125
# 1350 10 135
# 1450 10 145
# 1550 10 155
# 1650 10 165
# 1750 10 175
# 1850 10 185
# 1950 10 195
# 2050 11 186
# 2150 11 195
# 2250 11 204
# 2350 11 213
# 2450 11 222
# 2550 11 231
# 2650 11 240
# 2750 11 250
# 2850 11 259
# 2950 11 268
# 3050 11 277
# 3150 11 286
# 3250 11 295
# 3350 11 304
# 3450 11 313
# 3550 11 322
# 3650 11 331
# 3750 11 340
# 3850 11 350
# 3950 11 359
# 4050 11 368
# 4150 12 345
# 4250 12 354
# 4350 12 362
# 4450 12 370
# 4550 12 379
# 4650 12 387
# 4750 12 395
# 4850 12 404
# 4950 12 412
# 5050 12 420
# 5150 12 429
# 5250 12 437
# 5350 12 445
# 5450 12 454
# 5550 12 462
# 5650 12 470
# 5750 12 479
# 5850 12 487
# 5950 12 495
# 6050 12 504
# 6150 12 512
# 6250 12 520
# 6350 12 529
# 6450 12 537
# 6550 12 545
# 6650 12 554
# 6750 12 562
# 6850 12 570
# 6950 12 579
# 7050 12 587
# 7150 12 595
# 7250 12 604
# ...
